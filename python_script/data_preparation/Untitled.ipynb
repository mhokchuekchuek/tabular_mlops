# %%
import pandas as pd
df = pd.read_csv("/ml_data/ddproperty_final.csv").drop(columns = ["Unnamed: 0"])

# %%
list(df["price"][:25].values)
# Out:
# [8925000,
#  3300000,
#  8290000,
#  9900000,
#  8320000,
#  4650000,
#  10400000,
#  5500000,
#  16500000,
#  8000000,
#  10500000,
#  13500000,
#  12000000,
#  6490000,
#  6170000,
#  8431223,
#  3653634,
#  7500000,
#  7600000,
#  4800000,
#  2250000,
#  7300000,
#  3300000,
#  13300000,
#  8100000]

# %%
import sys
sys.path.append("/code/notebook")
from data_prep import preparation

# %%
preparation(df, "price")
# Out:
# /code/notebook/script/data_preparation/feature_engineering.py:33: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   a = pd.get_dummies(df_ja['feature'].explode()).sum(level=0)
# /code/notebook/script/data_preparation/feature_engineering.py:33: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   a = pd.get_dummies(df_ja['feature'].explode()).sum(level=0)
#          price  bedroom  bathroom     sqm  \
# 0      8925000        1         1   33.00
# 1      3300000        0         1   33.51
# 2      8290000        1         1   60.00
# 3      9900000        2         2   66.00
# 4      8320000        1         1   35.00
# ...        ...      ...       ...     ...
# ...

# %%
df = preparation(df, "price").info()
# Out:
# /code/notebook/script/data_preparation/feature_engineering.py:33: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   a = pd.get_dummies(df_ja['feature'].explode()).sum(level=0)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6366 entries, 0 to 7713
# Data columns (total 82 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   price                 6366 non-null   int64
#  1   bedroom               6366 non-null   int64
#  2   bathroom              6366 non-null   int64
#  3   sqm                   6366 non-null   float64
#  4   developer             6366 non-null   object
#  5   built_year            6366 non-null   int64
#  6   district              6366 non-null   object
#  7   luxuary               6366 non-null   int64
# ...

# %%
dtype('uint8'
# Out:
#   File "/tmp/ipykernel_235/1245343177.py", line 1
#     dtype('uint8'
#                  ^
# SyntaxError: unexpected EOF while parsing
